# %%
pip install tika
# Out:
# Requirement already satisfied: tika in c:\users\shrad\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: requests in c:\users\shrad\anaconda3\lib\site-packages (from tika) (2.28.1)
# Requirement already satisfied: setuptools in c:\users\shrad\anaconda3\lib\site-packages (from tika) (65.6.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shrad\anaconda3\lib\site-packages (from requests->tika) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shrad\anaconda3\lib\site-packages (from requests->tika) (2023.7.22)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\shrad\anaconda3\lib\site-packages (from requests->tika) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\shrad\anaconda3\lib\site-packages (from requests->tika) (1.26.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
#1753624 -- n rows in full data
import pandas as pd
import sqlite3
import requests
import tika
from tika import parser

# %%
# Should we use OCR if normal processing fails?
USE_OCR = False

class Bill:

    def __init__(self, bill_id, url, conn):
        self.bill_id = bill_id,
        self.url = url
        try:
            # A little cleaning for URLs that have moved domains
            self.url = self.url.replace("www.rilin.state.ri.us", "webserver.rilin.state.ri.us")
            self.url = self.url.replace('legis.sd.gov', 'sdlegislature.gov')
        except:
            pass
        self.conn = conn

    def update_content(self):
        self.content = None
        self.error = None

        try:
            headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
            response = requests.get(self.url, headers=headers, allow_redirects=True, timeout=2)
            print(response)

            # Send to tika
            tika_output = parser.from_buffer(response)

            # If we get nothing back, try OCR
            if USE_OCR and ('content' not in tika_output or not tika_output['content']):
                # headers = { 'X-Tika-PDFOcrStrategy': 'ocr_only' }
                headers = { 'X-Tika-PDFextractInlineImages': 'true' }
                tika_output = parser.from_buffer(response, headers=headers)

            if 'content' in tika_output and tika_output['content']:
                self.content = tika_output['content'].strip()        
            else:
                self.error = 'tika'
        except requests.exceptions.MissingSchema:
            self.error = 'bad_url'
        except requests.exceptions.Timeout:
            self.error = 'timeout'
        except requests.exceptions.ConnectionError:
            self.error = 'connection'
        
        self.save()
        
    def save(self):
        self.conn.execute("""
            UPDATE tBills 
            SET content=(?), 
                error=(?),  
                processed_at=(datetime('now','localtime'))
            WHERE bill_id = (?)
        ;""", (self.content, self.error, self.bill_id));
        
        UPDATE users 
SET field1 = 'value1',
    field2 = 'value2',
    field3 =  'value3';

    @classmethod
    def get(cls, conn, bill_id):
        results = conn.execute("""
            SELECT bill_id, url
            FROM tBills
            WHERE bill_id = (?)
            LIMIT 1;
        """, (bill_id,))
        print(results)
        # testing:
            # sql = """
            #     SELECT bill_id, url
            #     FROM tBills
            #     WHERE bill_id = (?)
            #     LIMIT 1;
            # """
            # params = (bill_id,)
            # results = pd.read_sql(sql, conn, params=params)
            # return results
        result = list(results)[0]
        return Bill(result[0], result[1], conn)
        
    @classmethod
    def unprocessed(cls, conn, limit=10):
        results = conn.execute("""
            SELECT bill_id, url
            FROM tBills
            WHERE processed_at IS NULL
            ORDER BY RANDOM()
            LIMIT = (%s)
        ;""")
        return [Bill(result[0], result[1], conn) for result in results]
    
    @classmethod
    def process_queue(cls, conn, limit=10):
        todo = Bill.unprocessed(conn, limit)
        for bill in todo:
            bill.update_content()

# %%
def connect_and_update(_):
    conn = sqlite3.connect('sample-data/legislation.db', isolation_level=None)
    Bill.process_queue(conn)
    conn.close()

# %%
conn = sqlite3.connect('sample-data/legislation.db', isolation_level=None)
curs = conn.cursor()

# %%
pd.read_sql("""
    SELECT
        COUNT(bill_id) - COUNT(processed_at) AS unprocessed,
        COUNT(processed_at) as processed,
        (COUNT(processed_at) / COUNT(bill_id)) * 100 as processed_pct
    FROM tBills
;""", conn)
# Out:
#    unprocessed  processed  processed_pct
# 0           88          0              0

# %%
pd.read_sql("SELECT * FROM tBills;", conn).head(3)
# Out:
#    bill_id bill_number                                              title  \
# 0   435129         HB1  Washington Co., judge of probate, fee for perf...
# 1   435133         HB2  Washington Co., judge of probate, fee for perf...
# 2   435135         HB3  Insurance Department, casualty insurance compa...
#
#                                          description state  \
# 0  Washington Co., judge of probate, fee for perf...    AL
# 1  Washington Co., judge of probate, fee for perf...    AL
# 2  Insurance Department, casualty insurance compa...    AL
#
#                       session  \
# 0  First Special Session 2012
# 1  First Special Session 2012
# 2  First Special Session 2012
#
#                                             filename  status status_date  \
# 0  ./sample-data\AL\2012-2012_1st_Special_Session...       2  2012-05-21
# 1  ./sample-data\AL\2012-2012_1st_Special_Session...       2  2012-05-21
# 2  ./sample-data\AL\2012-2012_1st_Special_Session...       1  2012-05-17
#
#   error content processed_at  \
# 0  None    None         None
# 1  None    None         None
# 2  None    None         None
#
#                                                  url
# 0  http://alisondb.legislature.state.al.us/ALISON...
# 1  http://alisondb.legislature.state.al.us/ALISON...
# 2  http://alisondb.legislature.state.al.us/ALISON...

# %%
try:
    conn.close()
except:
    pass

conn = sqlite3.connect('sample-data/legislation.db', isolation_level=None)
bill = Bill.get(conn, 435129)
bill.update_content()
print("Done")
conn.close()
# Out:
# <sqlite3.Cursor object at 0x0000019F3611AF80>
# <Response [200]>
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[358], line 8
#       6 conn = sqlite3.connect('sample-data/legislation.db', isolation_level=None)
#       7 bill = Bill.get(conn, 435129)
# ----> 8 bill.update_content()
#       9 print("Done")
#      10 conn.close()
#
# Cell In[353], line 46, in Bill.update_content(self)
#      43 except requests.exceptions.ConnectionError:
#      44     self.error = 'connection'
# ---> 46 self.save()
#
# Cell In[353], line 49, in Bill.save(self)
#      48 def save(self):
# ---> 49     self.conn.execute("""
#      50         UPDATE tBills SET content=(?), error=(?),  processed_at=(datetime('now','localtime'))
#      51         WHERE bill_id = (?)
#      52     ;""", (self.content, self.error, self.bill_id))
#
# InterfaceError: Error binding parameter 2 - probably unsupported type.
